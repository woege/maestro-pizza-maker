# %%
from maestro_pizza_maker import pizza_optimizer

# %%
pizza_min = pizza_optimizer.minimaze_price(
    constraints_values=pizza_optimizer.PizzaConstraintsValues(
        protein=pizza_optimizer.ValueBounds(min=10.0, max=10000.0),
        fat=pizza_optimizer.ValueBounds(min=10.0, max=10000.0),
        carbohydrates=pizza_optimizer.ValueBounds(min=10.0, max=10000.0),
        calories=pizza_optimizer.ValueBounds(min=10.0, max=10000.0),
    ),
    constraints_ingredients=pizza_optimizer.PizzaConstraintsIngredients(
        cheese=2,
        fruits=2,
        meat=2,
        vegetables=0,
        dough=1,
        sauce=1,
    ),
)
# Out:
# Welcome to the CBC MILP Solver
# Version: Trunk
# Build Date: Oct 24 2021
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0024I Matrix will be packed to eliminate 12 small elements
# Coin0506I Presolve 0 (-14) rows, 0 (-16) columns and 0 (-132) elements
# Clp0000I Optimal - objective value 7.5
# Coin0511I After Postsolve, objective 7.5, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 7.5 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
#
# Starting MIP optimization
# Cgl0002I 3 variables fixed
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc3007W No integer variables
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00

# %%
pizza_min
# Out:
# Pizza(dough=PizzaIngredient(name='WHOLEMEAL DOUGH', price=1.0, type=<IngredientType.DOUGH: 'dough'>, protein=10.0, fat=array([19.85924893, 19.54865072, 23.14888538, 27.52380028, 22.55913351,
#        18.79767313, 27.06136719, 22.3877676 , 22.828958  , 25.13635864,
#        21.85794164, 24.28942082, 21.70029528, 23.77705121, 26.88773101,
#        25.61955564, 25.84172922, 22.82098151, 20.51489842, 22.17551078,
#        25.13583828, 22.36636922, 20.56933199, 22.79607383, 24.90571714,
#        21.98613201, 21.3296072 , 21.23036601, 20.79915315, 21.3340327 ,
#        21.28651369, 21.83981099, 23.43130857, 17.75725058, 19.42196992,
#        25.25183894, 19.90985639, 22.5520144 , 21.90817361, 23.07547515,
#        24.64240974, 21.9618111 , 21.79921837, 23.1237534 , 24.84464461,
#        20.33194583, 22.44532954, 22.90277523, 25.68666173, 21.30101242,
#        21.70558065, 26.28049283, 22.64490064, 23.27815408, 19.16710776,
# ...
